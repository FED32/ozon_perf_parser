# %%
import pandas as pd
import numpy as np
from datetime import date
from datetime import datetime

from Ozon_performance_class import Ozon_performance
from Files_processing import db_working

# %%
# задаем рабочую папку
path = r'./data/test/'

# %%
# создаем экземпляр класса, проверяем соединение с базой
working = db_working()
working.test_db_connection()
# Out:
# ('PostgreSQL 14.4 (Ubuntu 14.4-201-yandex.52448.a37cfc9be3) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0, 64-bit',)

# %%
# загружаем таблицы с данными и ключами
working.get_analitics_data()
api_keys = working.get_perf_keys()
# Out:
# Загружена analitics_data
# Загружены performance_api_keys

# %%
# загружаем данные из БД в переменную, загружаем из БД последнюю дату
db_data = working.db_data
last_date = str(working.get_last_date())
print(last_date)
# Out:
# 2022-07-08

# %%
# переопределим для удобства чтобы получить больше данных и создать ситуацию для отработки фильтрации дубликатов
last_date = '2022-07-01'

# %%
date_from = last_date
date_to = str(date.today())

# %%
##загружаем статистику по каждому аккаунту
# for index, keys in api_keys.iterrows():
#     if len(keys[1]) > 0:
#         client_id = keys[1]
#         client_secret = keys[2]
#         account_id = keys[0]
#         ozon = Ozon_performance(account_id, client_id, client_secret, day_lim = 5, camp_lim = 5)
#         if ozon.auth:
#             ozon.collect_data(date_from = '2022-07-01', date_to = str(date.today()),
#                               methods = {'statistics': True, 'phrases': False, 'attribution': False, 
#                                          'media': False,'product': False, 'daily': False})
#             ozon.save_data(path = path, methods = {'statistics': True, 'phrases': False, 'attribution': False, 
#                                                      'media': False,'product': False, 'daily': False})

# %%
##распаковываем архивы
# working.extract_zips(path)

# %%
# создаем датасет на основе загруженных по API данных
dataset = working.make_dataset(path = path)

# %%
dataset
# Out:
#        actionnum      request_type                         viewtype  \
# 0        1070352         Категория             Безопасность ребенка
# 1        1070352         Категория                  Видеонаблюдение
# 2        1070352         Категория                  Видеонаблюдение
# 3        1070352         Категория  Камера видеонаблюдения для дома
# 4        1070352         Категория  Камера видеонаблюдения для дома
# ...          ...               ...                              ...
# 10024     999216  Поисковый запрос             набор защиты детский
# 10025     999216  Поисковый запрос             наколенники взрослые
# 10026     224647               NaN                              NaN
# 10027     224647               NaN                              NaN
# 10028     224647               NaN                              NaN
#
#                    platfrom  views  clicks   ctr  audience    cpm   api_id  \
# 0      Мобильное приложение    8.0     0.0  0.00       8.0  200.0  2471117
# 1      Мобильное приложение   79.0     2.0  2.53      81.0  200.0  2471117
# 2                   Десктоп   47.0     0.0  0.00      34.0  200.0  2471117
# 3      Мобильное приложение  115.0     8.0  6.96     108.0  200.0  2471117
# 4                   Десктоп   28.0     0.0  0.00      23.0  200.0  2471117
# ...                     ...    ...     ...   ...       ...    ...      ...
# 10024  Мобильное приложение    2.0     0.0  0.00       1.0  300.0  2490357
# 10025  Мобильное приложение    1.0     0.0  0.00       1.0  300.0  2490357
# 10026                   NaN    NaN     NaN   NaN       NaN    NaN  2490357
# 10027                   NaN    NaN     NaN   NaN       NaN    NaN  2490357
# 10028                   NaN    NaN     NaN   NaN       NaN    NaN  2490357
#
#        ...  articul search_price_perc search_price_rur exp_bonus        data  \
# 0      ...      NaN               NaN              NaN       NaN  2022-07-01
# 1      ...      NaN               NaN              NaN       NaN  2022-07-01
# 2      ...      NaN               NaN              NaN       NaN  2022-07-01
# 3      ...      NaN               NaN              NaN       NaN  2022-07-01
# 4      ...      NaN               NaN              NaN       NaN  2022-07-01
# ...    ...      ...               ...              ...       ...         ...
# 10024  ...      NaN               NaN              NaN       NaN  2022-07-08
# 10025  ...      NaN               NaN              NaN       NaN  2022-07-08
# 10026  ...      NaN               7.1       1276.39050       NaN  2022-07-06
# 10027  ...      NaN               7.1       1889.46945       NaN  2022-07-06
# 10028  ...      NaN               7.1        680.41050       NaN  2022-07-06
#
#                                                     name  orders    price  \
# 0                                                    nan     NaN      NaN
# 1                                                    nan     NaN      NaN
# 2                                                    nan     NaN      NaN
# 3                                                    nan     NaN      NaN
# 4                                                    nan     NaN      NaN
# ...                                                  ...     ...      ...
# 10024                                                nan     NaN      NaN
# 10025                                                nan     NaN      NaN
# 10026   Велосипед Welt Pony 20 2022 Mint Green (Дюйм:11)     1.0  17990.0
# 10027          BMX Велосипед Forward Zigzag 20, 20, 2021     1.0  26631.0
# 10028  Велосипед Welt Dingo 16 2020 Acid Green/Blue (...     1.0   9590.0
#
#        revenue     expense
# 0          NaN     1.60000
# 1          NaN    15.80000
# 2          NaN     9.40000
# 3          NaN    23.00000
# 4          NaN     5.60000
# ...        ...         ...
# 10024      NaN     0.60000
# 10025      NaN     0.30000
# 10026  17990.0  1276.39050
# 10027  26631.0  1889.46945
# 10028   9590.0   680.41050
#
# [10029 rows x 31 columns]

# %%
# разница в столбцах загруженного и БД
set(list(db_data.columns)).difference(set(list(dataset.columns)))
# Out:
# {'empty', 'id'}

# %%
# обработаем пропуски
dataset = dataset.fillna('nan')
db_data = db_data.fillna('nan')

dataset = dataset.replace('None', 'nan')
db_data = db_data.replace('None', 'nan')

# %%
# данные в базе после date_from отфильтрованные по загружаемым по api кампаниям
db_data_from = db_data[db_data['data'] <= datetime.strptime(date_to, '%Y-%m-%d').date()]
db_data_from = db_data_from[db_data_from['data'] >= datetime.strptime(date_from, '%Y-%m-%d').date()] 
db_data_from = db_data_from[db_data_from['actionnum'].isin(dataset.actionnum.unique())]

# %%
# # колонки по которым происходит поиск совпадений
# cols = ['actionnum', 'request_type', 'viewtype', 'platfrom', 'views', 'clicks', 'ctr', 'audience', 'cpm', 'banner',
#  'pagetype','sku', 'avrg_bid', 'orders_model', 'revenue_model', 'order_id', 'order_number', 'ozon_id', 
#  'ozon_id_ad_sku', 'articul', 'search_price_perc', 'search_price_rur', 'exp_bonus', 'data', 'name', 'orders',
#  'price', 'revenue', 'expense']
cols = ['actionnum', 'data', 'request_type', 'viewtype', 'platfrom', 'views', 'clicks', 'ctr', 'audience', 'cpm', 'expense',
       'order_id', 'order_number', 'ozon_id', 'ozon_id_ad_sku', 'articul', 'name', 'orders', 'price', 'revenue', 'search_price_perc', 'search_price_rur',]

# %%
# объединяем датасеты с удалением дубликатов
into_db = pd.concat([db_data_from, dataset], axis=0).reset_index().drop('index', axis=1).drop_duplicates(subset=cols, keep=False)

# %%
dataset.shape
# Out:
# (10029, 31)

# %%
db_data_from.shape
# Out:
# (16354, 33)

# %%
into_db.shape
# Out:
# (8610, 33)

# %%
into_db = into_db.replace('nan', np.nan)

# %%
into_db
# Out:
#               id banner pagetype                         viewtype  \
# 3      1304776.0    NaN      NaN                              NaN
# 82     1286954.0    NaN      NaN             Безопасность ребенка
# 83     1286955.0    NaN      NaN                  Видеонаблюдение
# 84     1286956.0    NaN      NaN                  Видеонаблюдение
# 85     1286957.0    NaN      NaN  Камера видеонаблюдения для дома
# ...          ...    ...      ...                              ...
# 26378        NaN    NaN      NaN             набор защиты детский
# 26379        NaN    NaN      NaN             наколенники взрослые
# 26380        NaN    NaN      NaN                              NaN
# 26381        NaN    NaN      NaN                              NaN
# 26382        NaN    NaN      NaN                              NaN
#
#                    platfrom      request_type  sku  \
# 3                       NaN               NaN  NaN
# 82     Мобильное приложение         Категория  NaN
# 83     Мобильное приложение         Категория  NaN
# 84                  Десктоп         Категория  NaN
# 85     Мобильное приложение         Категория  NaN
# ...                     ...               ...  ...
# 26378  Мобильное приложение  Поисковый запрос  NaN
# 26379  Мобильное приложение  Поисковый запрос  NaN
# 26380                   NaN               NaN  NaN
# 26381                   NaN               NaN  NaN
# 26382                   NaN               NaN  NaN
#
#                                                     name     order_id  \
# 3                                             Шапка Buff  755710443.0
# 82                                                   NaN          NaN
# 83                                                   NaN          NaN
# 84                                                   NaN          NaN
# 85                                                   NaN          NaN
# ...                                                  ...          ...
# 26378                                                NaN          NaN
# 26379                                                NaN          NaN
# 26380   Велосипед Welt Pony 20 2022 Mint Green (Дюйм:11)    757025785
# 26381          BMX Велосипед Forward Zigzag 20, 20, 2021    757564549
# 26382  Велосипед Welt Dingo 16 2020 Acid Green/Blue (...    757176888
#
#         order_number  ...    price orders  revenue_model  orders_model  \
# 3      65245036-0053  ...   2390.0    1.0            NaN           NaN
# 82               NaN  ...      NaN    NaN            NaN           NaN
# 83               NaN  ...      NaN    NaN            NaN           NaN
# 84               NaN  ...      NaN    NaN            NaN           NaN
# 85               NaN  ...      NaN    NaN            NaN           NaN
# ...              ...  ...      ...    ...            ...           ...
# 26378            NaN  ...      NaN    NaN            NaN           NaN
# 26379            NaN  ...      NaN    NaN            NaN           NaN
# 26380  59289451-0416  ...  17990.0    1.0            NaN           NaN
# 26381  13943418-0069  ...  26631.0    1.0            NaN           NaN
# 26382  29076101-0019  ...   9590.0    1.0            NaN           NaN
#
#        revenue     expense    cpm   ctr        data   api_id
# 3       2390.0    95.60000    NaN   NaN  2022-07-05  2490357
# 82         NaN     0.60000  200.0  0.00  2022-07-02  2471117
# 83         NaN     2.60000  200.0  0.00  2022-07-02  2471117
# 84         NaN     0.20000  200.0  0.00  2022-07-02  2471117
# 85         NaN     7.40000  200.0  8.11  2022-07-02  2471117
# ...        ...         ...    ...   ...         ...      ...
# 26378      NaN     0.60000  300.0  0.00  2022-07-08  2490357
# 26379      NaN     0.30000  300.0  0.00  2022-07-08  2490357
# 26380  17990.0  1276.39050    NaN   NaN  2022-07-06  2490357
# 26381  26631.0  1889.46945    NaN   NaN  2022-07-06  2490357
# 26382   9590.0   680.41050    NaN   NaN  2022-07-06  2490357
#
# [8610 rows x 33 columns]
